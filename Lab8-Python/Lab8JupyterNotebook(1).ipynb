# %% [markdown]
#  Lab 8

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Loading a dataset:
iris_dataframe = pd.read_csv('IrisDataset/IrisDataset/Iris.csv')

# %%
iris_dataframe
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
iris_dataframe.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris_dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
iris_dataframe["Species"].value_counts()
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %% [markdown]
# 1. Line Plot

# %%
plt.plot(iris_dataframe["Id"], iris_dataframe['SepalWidthCm'])
plt.title("Iris Sepal Length")
plt.xlabel("Id")
plt.ylabel("Sepal Width (cm)")
# Out:
# Text(0, 0.5, 'Sepal Width (cm)')

# %%
# adding gird-lines
plt.grid(True)

plt.plot(iris_dataframe["Id"], iris_dataframe['SepalLengthCm'])
plt.title("Iris Sepal Length")
plt.xlabel("Id")
plt.ylabel("Sepal Length (cm)")
# Set x-axis for every 10 units
plt.xticks(range(0, max(iris_dataframe["Id"]) + 1, 20))  
plt.show()

# %% [markdown]
# 2. Scatter Plot

# %%
plt.grid(True)
plt.scatter(iris_dataframe["SepalLengthCm"], iris_dataframe["SepalWidthCm"])
plt.title("Iris Sepal Length vs Width")
plt.xlabel("Sepal Length (cm)")
plt.ylabel("Sepal Width (cm)")
# Out:
# Text(0, 0.5, 'Sepal Width (cm)')

# %% [markdown]
# 3. Multivariate

# %%
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50

iris_species_color = {"Iris-setosa": "yellow", 
                      "Iris-versicolor": "red", 
                      "Iris-virginica":"blue"}

for species, species_color in iris_species_color.items():
    # creating a data frame for a specific value for 'Species' column:
    species_dataframe = iris_dataframe[iris_dataframe["Species"] == species]
    # parameter c - color
    plt.scatter(species_dataframe["PetalLengthCm"], species_dataframe["PetalWidthCm"], c = species_color, label=species)

plt.grid(True)
plt.title("Iris Sepal Length vs Width")
plt.xlabel("Sepal Length (cm)")
plt.ylabel("Sepal Width (cm)")
plt.legend()

# %% [markdown]
# 4. Histogram

# %%
sns.histplot(data=iris_dataframe, x="SepalLengthCm")
plt.title("Sepal Length Distribution")
plt.xlabel("Sepal Length (cm)")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
sns.histplot(data=iris_dataframe, x="SepalLengthCm")
plt.title("Sepal Length Distribution")
plt.grid(axis="y")
plt.xlabel("Sepal Length (cm)")
plt.ylabel("Count")
plt.yticks(range(0, 30, 2))
# Out:
# ([<matplotlib.axis.YTick at 0x1075e0b20>,
# ...
#  [Text(0, 0, '0'),
#   Text(0, 2, '2'),
#   Text(0, 4, '4'),
#   Text(0, 6, '6'),
#   Text(0, 8, '8'),
#   Text(0, 10, '10'),
#   Text(0, 12, '12'),
#   Text(0, 14, '14'),
#   Text(0, 16, '16'),
#   Text(0, 18, '18'),
#   Text(0, 20, '20'),
#   Text(0, 22, '22'),
#   Text(0, 24, '24'),
#   Text(0, 26, '26'),
#   Text(0, 28, '28')])

# %% [markdown]
# ## Pair Plot
# Introduce pairwise relationships.

# %%
sns.pairplot(iris_dataframe)
plt.show()
